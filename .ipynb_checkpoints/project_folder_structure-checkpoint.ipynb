# %%
# Cell 1: Create the project folder and subfolders
import os

# Create project on your Desktop
PROJECT_DIR = os.path.expanduser("~/Desktop/grant_monitor_app")
TEMPLATES_DIR = os.path.join(PROJECT_DIR, "templates")

os.makedirs(TEMPLATES_DIR, exist_ok=True)

print(f"✅ Project folder: {PROJECT_DIR}")
print(f"✅ Templates folder: {TEMPLATES_DIR}")
print(f"\nContents:")
for item in os.listdir(PROJECT_DIR):
    print(f"   📁 {item}" if os.path.isdir(os.path.join(PROJECT_DIR, item)) else f"   📄 {item}")

# %%
# Cell 2: Write requirements.txt

requirements = """flask
pywebview
requests
beautifulsoup4
feedparser
pandas
lxml
openpyxl
python-dateutil
"""

with open(os.path.join(PROJECT_DIR, "requirements.txt"), "w") as f:
    f.write(requirements)

print("✅ requirements.txt written")

# %%
# Check the full path to your project and list all files

import os

PROJECT_DIR = os.path.expanduser("~/Desktop/grant_monitor_app")

print("=" * 60)
print("📁 PROJECT LOCATION")
print("=" * 60)
print(f"\n   Full path: {PROJECT_DIR}")
print(f"   Exists:    {os.path.exists(PROJECT_DIR)}")
print()

# List all files with sizes
print("📄 FILES:")
print("-" * 60)
total_size = 0
for root, dirs, files in os.walk(PROJECT_DIR):
    # Skip hidden folders like.git
    dirs[:] = [d for d in dirs if not d.startswith(".")]
    for file in files:
        if file.startswith("."):
            continue
        filepath = os.path.join(root, file)
        rel_path = os.path.relpath(filepath, PROJECT_DIR)
        size = os.path.getsize(filepath)
        total_size += size
        print(f"   {rel_path:<40} {size:>8,} bytes")

print("-" * 60)
print(f"   Total: {total_size:,} bytes ({total_size/1024:.1f} KB)")

print()
print("=" * 60)
print("🔗 GIT COMMANDS (copy/paste into Terminal)")
print("=" * 60)
print(f"""
   cd {PROJECT_DIR}
   git init
   git add.
   git commit -m "Initial commit: Grant Monitor desktop app"
   git branch -M main
   git remote add origin https://github.com/YOUR_USERNAME/YOUR_REPO.git
   git push -u origin main
""")

print("=" * 60)
print("💡 TIPS")
print("=" * 60)
print("""
   1. Create a new repo on GitHub first:
      https://github.com/new

   2. Replace YOUR_USERNAME/YOUR_REPO with your actual repo name

   3. Don't forget to add a.gitignore (see next cell)
""")
# Out:
# ...
# 📁 PROJECT LOCATION
# ...
#
#    Full path: /Users/kschro10/Desktop/grant_monitor_app
#    Exists:    False
#
# 📄 FILES:
# ------------------------------------------------------------
# ------------------------------------------------------------
#    Total: 0 bytes (0.0 KB)
#
# ...
# 🔗 GIT COMMANDS (copy/paste into Terminal)
# ...
#
#    cd /Users/kschro10/Desktop/grant_monitor_app
#    git init
#    git add.
#    git commit -m "Initial commit: Grant Monitor desktop app"
#    git branch -M main
#    git remote add origin https://github.com/YOUR_USERNAME/YOUR_REPO.git
#    git push -u origin main
#
# ...
# 💡 TIPS
# ...
#
#    1. Create a new repo on GitHub first:
#       https://github.com/new
#
#    2. Replace YOUR_USERNAME/YOUR_REPO with your actual repo name
#
#    3. Don't forget to add a.gitignore (see next cell)

# %%
# Find the actual project folder

import os
import subprocess

# Method 1: Check the variable if it's still in memory
try:
    print(f"PROJECT_DIR variable: {PROJECT_DIR}")
    print(f"Exists: {os.path.exists(PROJECT_DIR)}")
except NameError:
    print("PROJECT_DIR variable not set in this session")

print()

# Method 2: Search for the app.py we created
print("🔍 Searching for grant_monitor_app folders on your system...")
print("   (this may take a moment)\n")

result = subprocess.run(
    ["find", os.path.expanduser("~"), "-type", "d", "-name", "grant_monitor_app", "-maxdepth", "5"],
    capture_output=True, text=True, timeout=30
)

if result.stdout.strip():
    for path in result.stdout.strip().split("\n"):
        print(f"   📁 Found: {path}")
        # List contents
        for item in os.listdir(path):
            full = os.path.join(path, item)
            icon = "📁" if os.path.isdir(full) else "📄"
            print(f"      {icon} {item}")
        print()
else:
    print("   ❌ No 'grant_monitor_app' folder found")
    print()
    print("   Let's check your current Jupyter working directory instead:")
    cwd = os.getcwd()
    print(f"   📁 Current directory: {cwd}")
    print()
    for item in os.listdir(cwd):
        full = os.path.join(cwd, item)
        icon = "📁" if os.path.isdir(full) else "📄"
        size = os.path.getsize(full) if os.path.isfile(full) else ""
        print(f"      {icon} {item}  {size}")
# Out:
# PROJECT_DIR variable: /Users/kschro10/Desktop/grant_monitor_app
# Exists: False
#
# 🔍 Searching for grant_monitor_app folders on your system...
#    (this may take a moment)
#
#    ❌ No 'grant_monitor_app' folder found
#
#    Let's check your current Jupyter working directory instead:
#    📁 Current directory: /Users/kschro10/anaconda_projects/1b55a599-cf36-4af0-9a0e-86dc28da2d79
#
#       📄 project_folder_structure.ipynb  5886
#       📁 .ipynb_checkpoints
